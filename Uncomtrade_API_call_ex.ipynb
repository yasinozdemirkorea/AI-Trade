# %% [markdown]
# <a href="https://colab.research.google.com/github/datadigger01/AI-Trade/blob/main/Uncomtrade_API_call_ex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install a pip comtradeapicall package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install --upgrade comtradeapicall

# %%
import pandas
import requests
import comtradeapicall

# %%
# comtrade api subscription key (from comtradedeveloper.un.org)

subscription_key = '########################'

# %%
# comtradeapicall 사용 : https://github.com/uncomtrade/comtradeapicall 내용 참조

mydf = comtradeapicall.getFinalData(subscription_key, typeCode='C', freqCode='A', clCode='HS', period='2024',
                                    reporterCode=None, cmdCode='090190', flowCode='X', partnerCode=None,
                                    partner2Code=None,
                                    customsCode=None, motCode=None, maxRecords=10000, format_output='JSON',
                                    aggregateBy=None, breakdownMode='classic', countOnly=None, includeDesc=True)
mydf
# Out:
#      typeCode freqCode  refPeriodId  refYear  refMonth period  reporterCode  \
# 0           C        A     20240101     2024        52   2024            28
# 1           C        A     20240101     2024        52   2024            28
# 2           C        A     20240101     2024        52   2024            31
# 3           C        A     20240101     2024        52   2024            31
# 4           C        A     20240101     2024        52   2024            36
# ...       ...      ...          ...      ...       ...    ...           ...
# 1192        C        A     20240101     2024        52   2024           842
# 1193        C        A     20240101     2024        52   2024           842
# 1194        C        A     20240101     2024        52   2024           842
# 1195        C        A     20240101     2024        52   2024           854
# 1196        C        A     20240101     2024        52   2024           854
#
# ...

# %%
# output directory for downloaded files

directory = '/content/drive/MyDrive/~~~~~~~~'

# %%
import os

# Create the directory if it doesn't exist
os.makedirs(directory, exist_ok=True)

# Save the DataFrame to a CSV file
output_file = os.path.join(directory, 'mydf_data.csv')
mydf.to_csv(output_file, index=False)

print(f"DataFrame saved to {output_file}")
# Out:
# DataFrame saved to /content/drive/MyDrive/AI와무역투자론/Data/mydf_data.csv

# %% [markdown]
# ### reporter(수출국)/partner(수입국) 코드 확인하는 방법

# %%
reporter = comtradeapicall.getReference('reporter')
partner = comtradeapicall.getReference('partner')

reporter

# %%
reporter[reporter['reporterDesc'].str.contains('Korea')]
#partner[partner['PartnerDesc'].str.contains('Korea')]
# Korea Code : 410

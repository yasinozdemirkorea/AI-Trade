# %% [markdown]
# <a href="https://colab.research.google.com/github/datadigger01/AI-Trade/blob/main/File_upload_ex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/AI와무역투자론/Data/TradeData_9_12_2025_6_14_15.csv", encoding='latin-1')
df
# Out:
#    typeCode  freqCode  refPeriodId  refYear  refMonth  period reporterCode  \
# C         A  20240101         2024       52      2024       8          ALB
# C         A  20240101         2024       52      2024       8          ALB
# C         A  20240101         2024       52      2024       8          ALB
# C         A  20240101         2024       52      2024       8          ALB
# C         A  20240101         2024       52      2024       8          ALB
# ..      ...       ...          ...      ...       ...     ...          ...
# C         A  20240101         2024       52      2024     854          BFA
# C         A  20240101         2024       52      2024     860          UZB
# C         A  20240101         2024       52      2024     860          UZB
# C         A  20240101         2024       52      2024     860          UZB
# C         A  20240101         2024       52      2024     860          UZB
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3914 entries, C to C
# Data columns (total 47 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   typeCode                  3914 non-null   object
#  1   freqCode                  3914 non-null   int64
#  2   refPeriodId               3914 non-null   int64
#  3   refYear                   3914 non-null   int64
#  4   refMonth                  3914 non-null   int64
#  5   period                    3914 non-null   int64
#  6   reporterCode              3914 non-null   object
#  7   reporterISO               3914 non-null   object
#  8   reporterDesc              3914 non-null   object
#  9   flowCode                  3914 non-null   object
#  10  flowDesc                  3914 non-null   int64
#  11  partnerCode               3914 non-null   object
#  12  partnerISO                3914 non-null   object
#  13  partnerDesc               3914 non-null   int64
# ...

# %%
df.describe()
# Out:
#          freqCode  refPeriodId  refYear  refMonth       period     flowDesc  \
# count      3914.0       3914.0   3914.0    3914.0  3914.000000  3914.000000
# mean   20240101.0       2024.0     52.0    2024.0   450.423863   434.959121
# std           0.0          0.0      0.0       0.0   261.948980   257.826913
# min    20240101.0       2024.0     52.0    2024.0     8.000000     0.000000
# 25%    20240101.0       2024.0     52.0    2024.0   222.000000   208.000000
# 50%    20240101.0       2024.0     52.0    2024.0   440.000000   428.000000
# 75%    20240101.0       2024.0     52.0    2024.0   705.000000   682.000000
# max    20240101.0       2024.0     52.0    2024.0   860.000000   899.000000
#
#        partnerDesc  isOriginalClassification  cmdDesc  customsDesc  ...  \
# count       3914.0                    3914.0   3914.0       3914.0  ...
# mean           0.0                     901.0      4.0          0.0  ...
# ...
